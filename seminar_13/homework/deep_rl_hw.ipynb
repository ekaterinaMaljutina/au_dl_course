# %%
import gym
import pylab
import random
import numpy as np
from collections import deque
# import tflearn

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras import optimizers
from keras.layers import BatchNormalization
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Task: fill empty spaces in the following agent code

# %%
class DeepQAgent:
    def __init__(self, state_size, action_size, render=True):
        # Tip: if you are training this on AWS the best way is to turn off rendering
        # and load it later with the serialized model
        self.render = render
        self.state_size = state_size
        self.action_size = action_size

        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_min = 0.005
        self.epsilon_decay = (self.epsilon - self.epsilon_min) / 50000
        self.batch_size = 64
        self.train_start = 1000
        # replay memory
        self.memory = deque(maxlen=10000)

        self.model = self.build_model()
        self.target_model = self.build_model()
        self.update_target_model()

    def build_model(self):
        # Use tflearn to get simple NN for deep q-learning
        # Spoler alert: a couple of fully connected hidden layers should be enough
        # Output layer should have the same dimensionality as the action space
#         TODO
#         model = Sequential()
#         model.add(Dense(64, input_shape=(self.state_size,), activation='relu'))
# #         model.add(BatchNormalization(trainable = True))
#         model.add(Dense(64, activation='relu'))
#         #         model.add(BatchNormalization(trainable = True))
#         model.add(Dense(self.action_size, activation='linear'))
#         model.compile(
#             loss='mse',
#             optimizer=optimizers.Adam(lr=self.learning_rate)
# #                                       beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
#         )
#         print(model.summary())
#         return model

#         model = Sequential()
#         model.add(Dense(64, input_shape=(self.state_size, ), activation='relu'))
#         model.add(Dense(self.state_size, activation='relu'))
#         model.add(Dense(self.action_size))
#         model.compile(optimizer=optimizers.Adam(lr=self.learning_rate),loss='mse')
#         print(model.summary())
#         return model


        model = Sequential()
        
        model.add(Dense(64, activation='relu', input_dim = self.state_size))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        
        model.compile(optimizers.Adam(lr=self.learning_rate), 'mse')
        print(model.summary())
        return model

    def update_target_model(self):
        """Update your target model to the model you are currently learning at regular time intervals"""
        self.target_model.set_weights(self.model.get_weights())

    def get_action(self, state):
        """The choice of action uses the epsilon-greedy policy for the current network."""
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])

    def replay_memory(self, state, action, reward, next_state, done):
        """Save <s, a, r, s'> to replay_memory"""
        if action == 2:
            action = 1
        self.memory.append((state, action, reward, next_state, done))
        if self.epsilon > self.epsilon_min:
            self.epsilon -= self.epsilon_decay
            # print(len(self.memory))

    def train_replay(self):
        """Random sampling of batch_size samples from replay memory"""
        if len(self.memory) < self.train_start:
            return
        batch_size = min(self.batch_size, len(self.memory))
        mini_batch = random.sample(self.memory, batch_size)

        update_input = np.zeros((batch_size, self.state_size))
        update_target = np.zeros((batch_size, self.action_size))

        for i in range(batch_size):
            state, action, reward, next_state, done = mini_batch[i]
            target = self.model.predict(state)[0]
            
            
#             target[action] = reward
            # As in queuing, it gets the maximum Q Value at s'. However, it is imported from the target model.
            if done:
                target[action] = reward
            else:
                target[action] = reward + self.discount_factor * \
                                          np.amax(self.target_model.predict(next_state)[0])
            update_input[i] = state
            update_target[i] = target

        # You can create a minibatch of the correct target answer and the current value of your own,
        self.model.fit(update_input, update_target, batch_size=batch_size, epochs=1, verbose=0)

    def load_model(self, name):
        self.model.load_weights(name, by_name=True)

    def save_model(self, name):
        self.model.save(name)

# %%
env = gym.make('MountainCar-v0')
state_size = env.observation_space.shape[0] # should be equal 2
ACTION_SIZE = 2
del agent
agent = DeepQAgent(state_size, ACTION_SIZE)
# agent.load_model("./save_model/<your_saved_model_name>")
scores, episodes = [], []
N_EPISODES = 500
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 64)                192
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_22 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 6,498
# Trainable params: 6,498
# Non-trainable params: 0
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 64)                192
# _________________________________________________________________
# dense_24 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_25 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 6,498
# Trainable params: 6,498
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# agent.load_model('./save_model/model_new1_1')

# %%
for e in range(N_EPISODES):
    done = False
    score = 0
    state = env.reset()
    state = np.reshape(state, [1, state_size])
#     print(state)

    # Action 0 (left), 1 (do nothing), 3 (declare fake_action to avoid doing nothing
    fake_action = 0

    # Counter for the same action 4 times
    action_count = 0

    while not done:
        if agent.render:
            env.render()

        # Select an action in the current state and proceed to a step
        action_count = action_count + 1

        if action_count == 4:
            action = agent.get_action(state)
            action_count = 0

            if action == 0:
                fake_action = 0
            elif action == 1:
                fake_action = 2

        # Take 1 step with the selected action
        next_state, reward, done, info = env.step(fake_action)
        next_state = np.reshape(next_state, [1, state_size])
        # Give a penalty of -100 for actions that end an episode
        # reward = reward if not done else -100

        # Save <s, a, r, s'> to replay memory
        agent.replay_memory(state, fake_action, reward, next_state, done)
        # Continue to learn every time step
        agent.train_replay()
        score += reward
        state = next_state

        if done:
            env.reset()
            # Copy the learning model for each episode to the target model
            agent.update_target_model()

            # For each episode, the time step where cartpole stood is plot
            scores.append(score)
            episodes.append(e)
            print("episode:", e, "  score:", score, "  memory length:", len(agent.memory),
                  "  epsilon:", agent.epsilon)

    # Save model for every 50 episodes
    if e % 50 == 0:
        agent.save_model("./save_model/model_new1_1_1")
# Out:
# ('episode:', 0, '  score:', -200.0, '  memory length:', 200, '  epsilon:', 0.9960200000000077)
# ('episode:', 1, '  score:', -200.0, '  memory length:', 400, '  epsilon:', 0.9920400000000154)
# ('episode:', 2, '  score:', -200.0, '  memory length:', 600, '  epsilon:', 0.988060000000023)
# ('episode:', 3, '  score:', -200.0, '  memory length:', 800, '  epsilon:', 0.9840800000000307)
# ('episode:', 4, '  score:', -200.0, '  memory length:', 1000, '  epsilon:', 0.9801000000000384)
# ('episode:', 5, '  score:', -200.0, '  memory length:', 1200, '  epsilon:', 0.9761200000000461)
# ('episode:', 6, '  score:', -200.0, '  memory length:', 1400, '  epsilon:', 0.9721400000000537)
# ('episode:', 7, '  score:', -200.0, '  memory length:', 1600, '  epsilon:', 0.9681600000000614)
# ('episode:', 8, '  score:', -200.0, '  memory length:', 1800, '  epsilon:', 0.9641800000000691)
# ('episode:', 9, '  score:', -200.0, '  memory length:', 2000, '  epsilon:', 0.9602000000000768)
# ('episode:', 10, '  score:', -200.0, '  memory length:', 2200, '  epsilon:', 0.9562200000000844)
# ('episode:', 11, '  score:', -200.0, '  memory length:', 2400, '  epsilon:', 0.9522400000000921)
# ('episode:', 12, '  score:', -200.0, '  memory length:', 2600, '  epsilon:', 0.9482600000000998)
# ('episode:', 13, '  score:', -200.0, '  memory length:', 2800, '  epsilon:', 0.9442800000001075)
# ('episode:', 14, '  score:', -200.0, '  memory length:', 3000, '  epsilon:', 0.9403000000001152)
# ('episode:', 15, '  score:', -200.0, '  memory length:', 3200, '  epsilon:', 0.9363200000001228)
# ('episode:', 16, '  score:', -200.0, '  memory length:', 3400, '  epsilon:', 0.9323400000001305)
# ('episode:', 17, '  score:', -200.0, '  memory length:', 3600, '  epsilon:', 0.9283600000001382)
# ('episode:', 18, '  score:', -200.0, '  memory length:', 3800, '  epsilon:', 0.9243800000001459)
# ('episode:', 19, '  score:', -200.0, '  memory length:', 4000, '  epsilon:', 0.9204000000001535)
# ('episode:', 20, '  score:', -200.0, '  memory length:', 4200, '  epsilon:', 0.9164200000001612)
# ('episode:', 21, '  score:', -200.0, '  memory length:', 4400, '  epsilon:', 0.9124400000001689)
# ('episode:', 22, '  score:', -200.0, '  memory length:', 4600, '  epsilon:', 0.9084600000001766)
# ('episode:', 23, '  score:', -200.0, '  memory length:', 4800, '  epsilon:', 0.9044800000001842)
# ('episode:', 24, '  score:', -200.0, '  memory length:', 5000, '  epsilon:', 0.9005000000001919)
# ('episode:', 25, '  score:', -200.0, '  memory length:', 5200, '  epsilon:', 0.8965200000001996)
# ('episode:', 26, '  score:', -200.0, '  memory length:', 5400, '  epsilon:', 0.8925400000002073)
# ('episode:', 27, '  score:', -200.0, '  memory length:', 5600, '  epsilon:', 0.888560000000215)
# ('episode:', 28, '  score:', -200.0, '  memory length:', 5800, '  epsilon:', 0.8845800000002226)
# ('episode:', 29, '  score:', -200.0, '  memory length:', 6000, '  epsilon:', 0.8806000000002303)
# ('episode:', 30, '  score:', -200.0, '  memory length:', 6200, '  epsilon:', 0.876620000000238)
# ('episode:', 31, '  score:', -200.0, '  memory length:', 6400, '  epsilon:', 0.8726400000002457)
# ('episode:', 32, '  score:', -200.0, '  memory length:', 6600, '  epsilon:', 0.8686600000002533)
# ('episode:', 33, '  score:', -200.0, '  memory length:', 6800, '  epsilon:', 0.864680000000261)
# ('episode:', 34, '  score:', -200.0, '  memory length:', 7000, '  epsilon:', 0.8607000000002687)
# ('episode:', 35, '  score:', -200.0, '  memory length:', 7200, '  epsilon:', 0.8567200000002764)
# ('episode:', 36, '  score:', -200.0, '  memory length:', 7400, '  epsilon:', 0.852740000000284)
# ('episode:', 37, '  score:', -200.0, '  memory length:', 7600, '  epsilon:', 0.8487600000002917)
# ('episode:', 38, '  score:', -200.0, '  memory length:', 7800, '  epsilon:', 0.8447800000002994)
# ('episode:', 39, '  score:', -200.0, '  memory length:', 8000, '  epsilon:', 0.8408000000003071)
# ('episode:', 40, '  score:', -200.0, '  memory length:', 8200, '  epsilon:', 0.8368200000003148)
# ('episode:', 41, '  score:', -200.0, '  memory length:', 8400, '  epsilon:', 0.8328400000003224)
# ('episode:', 42, '  score:', -200.0, '  memory length:', 8600, '  epsilon:', 0.8288600000003301)
# ('episode:', 43, '  score:', -200.0, '  memory length:', 8800, '  epsilon:', 0.8248800000003378)
# ('episode:', 44, '  score:', -200.0, '  memory length:', 9000, '  epsilon:', 0.8209000000003455)
# ('episode:', 45, '  score:', -200.0, '  memory length:', 9200, '  epsilon:', 0.8169200000003531)
# ('episode:', 46, '  score:', -200.0, '  memory length:', 9400, '  epsilon:', 0.8129400000003608)
# ('episode:', 47, '  score:', -200.0, '  memory length:', 9600, '  epsilon:', 0.8089600000003685)
# ('episode:', 48, '  score:', -200.0, '  memory length:', 9800, '  epsilon:', 0.8049800000003762)
# ('episode:', 49, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.8010000000003838)
# ('episode:', 50, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7970200000003915)
# ('episode:', 51, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7930400000003992)
# ('episode:', 52, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7890600000004069)
# ('episode:', 53, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7850800000004146)
# ('episode:', 54, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7811000000004222)
# ('episode:', 55, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7771200000004299)
# ('episode:', 56, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7731400000004376)
# ('episode:', 57, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7691600000004453)
# ('episode:', 58, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7651800000004529)
# ('episode:', 59, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7612000000004606)
# ('episode:', 60, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7572200000004683)
# ('episode:', 61, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.753240000000476)
# ('episode:', 62, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7492600000004837)
# ('episode:', 63, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7452800000004913)
# ('episode:', 64, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.741300000000499)
# ('episode:', 65, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7373200000005067)
# ('episode:', 66, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7333400000005144)
# ('episode:', 67, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.729360000000522)
# ('episode:', 68, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7253800000005297)
# ('episode:', 69, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7214000000005374)
# ('episode:', 70, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7174200000005451)
# ('episode:', 71, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7134400000005527)
# ('episode:', 72, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7094600000005604)
# ('episode:', 73, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7054800000005681)
# ('episode:', 74, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.7015000000005758)
# ('episode:', 75, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6975200000005835)
# ('episode:', 76, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6935400000005911)
# ('episode:', 77, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6895600000005988)
# ('episode:', 78, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6855800000006065)
# ('episode:', 79, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6816000000006142)
# ('episode:', 80, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6776200000006218)
# ('episode:', 81, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6736400000006295)
# ('episode:', 82, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6696600000006372)
# ('episode:', 83, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6656800000006449)
# ('episode:', 84, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6617000000006525)
# ('episode:', 85, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6577200000006602)
# ('episode:', 86, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6537400000006679)
# ('episode:', 87, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6497600000006756)
# ('episode:', 88, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6457800000006833)
# ('episode:', 89, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6418000000006909)
# ('episode:', 90, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6378200000006986)
# ('episode:', 91, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6338400000007063)
# ('episode:', 92, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.629860000000714)
# ('episode:', 93, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6258800000007216)
# ('episode:', 94, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6219000000007293)
# ('episode:', 95, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.617920000000737)
# ('episode:', 96, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6139400000007447)
# ('episode:', 97, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6099600000007523)
# ('episode:', 98, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.60598000000076)
# ('episode:', 99, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.6020000000007677)
# ('episode:', 100, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.5980200000007754)
# ('episode:', 101, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.594040000000783)
# ('episode:', 102, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.
'  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.09514700000081115)
# ('episode:', 232, '  score:', -86.0, '  memory length:', 10000, '  epsilon:', 0.09343560000081087)
# ('episode:', 233, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.08945560000081022)
# ('episode:', 234, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.08547560000080957)
# ('episode:', 235, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.08149560000080892)
# ('episode:', 236, '  score:', -189.0, '  memory length:', 10000, '  epsilon:', 0.07773450000080831)
# ('episode:', 237, '  score:', -171.0, '  memory length:', 10000, '  epsilon:', 0.07433160000080775)
# ('episode:', 238, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.0703516000008071)
# ('episode:', 239, '  score:', -172.0, '  memory length:', 10000, '  epsilon:', 0.06692880000080655)
# ('episode:', 240, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.06460050000080617)
# ('episode:', 241, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.060620500000805516)
# ('episode:', 242, '  score:', -124.0, '  memory length:', 10000, '  epsilon:', 0.05815290000080511)
# ('episode:', 243, '  score:', -141.0, '  memory length:', 10000, '  epsilon:', 0.055347000000804655)
# ('episode:', 244, '  score:', -124.0, '  memory length:', 10000, '  epsilon:', 0.05287940000080425)
# ('episode:', 245, '  score:', -123.0, '  memory length:', 10000, '  epsilon:', 0.05043170000080385)
# ('episode:', 246, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.04714820000080332)
# ('episode:', 247, '  score:', -136.0, '  memory length:', 10000, '  epsilon:', 0.044441800000802875)
# ('episode:', 248, '  score:', -175.0, '  memory length:', 10000, '  epsilon:', 0.04095930000080231)
# ('episode:', 249, '  score:', -181.0, '  memory length:', 10000, '  epsilon:', 0.03735740000080172)
# ('episode:', 250, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.03413360000080119)
# ('episode:', 251, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.031088900000800727)
# ('episode:', 252, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.02710890000080077)
# ('episode:', 253, '  score:', -172.0, '  memory length:', 10000, '  epsilon:', 0.02368610000080081)
# ('episode:', 254, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.020581700000800843)
# ('episode:', 255, '  score:', -189.0, '  memory length:', 10000, '  epsilon:', 0.016820600000800885)
# ('episode:', 256, '  score:', -123.0, '  memory length:', 10000, '  epsilon:', 0.014372900000800912)
# ('episode:', 257, '  score:', -139.0, '  memory length:', 10000, '  epsilon:', 0.011606800000800943)
# ('episode:', 258, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.008601900000800976)
# ('episode:', 259, '  score:', -145.0, '  memory length:', 10000, '  epsilon:', 0.0057164000008010085)
# ('episode:', 260, '  score:', -151.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 261, '  score:', -156.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 262, '  score:', -137.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 263, '  score:', -125.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 264, '  score:', -86.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 265, '  score:', -195.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 266, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 267, '  score:', -146.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 268, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 269, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 270, '  score:', -148.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 271, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 272, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 273, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 274, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 275, '  score:', -83.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 276, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 277, '  score:', -134.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 278, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 279, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 280, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 281, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 282, '  score:', -143.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 283, '  score:', -163.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 284, '  score:', -146.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 285, '  score:', -86.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 286, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 287, '  score:', -147.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 288, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 289, '  score:', -159.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 290, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 291, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 292, '  score:', -152.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 293, '  score:', -142.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 294, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 295, '  score:', -163.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 296, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 297, '  score:', -200.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 298, '  score:', -145.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 299, '  score:', -160.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 300, '  score:', -158.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 301, '  score:', -199.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 302, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 303, '  score:', -138.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 304, '  score:', -145.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 305, '  score:', -141.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 306, '  score:', -145.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 307, '  score:', -192.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 308, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 309, '  score:', -133.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 310, '  score:', -135.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 311, '  score:', -127.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 312, '  score:', -129.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 313, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 314, '  score:', -141.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 315, '  score:', -109.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 316, '  score:', -90.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 317, '  score:', -154.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 318, '  score:', -133.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 319, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 320, '  score:', -153.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 321, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 322, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 323, '  score:', -133.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 324, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 325, '  score:', -145.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 326, '  score:', -164.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 327, '  score:', -122.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 328, '  score:', -133.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 329, '  score:', -114.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 330, '  score:', -131.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 331, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 332, '  score:', -128.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 333, '  score:', -136.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 334, '  score:', -114.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 335, '  score:', -132.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 336, '  score:', -133.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 337, '  score:', -123.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 338, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 339, '  score:', -123.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 340, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 341, '  score:', -160.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 342, '  score:', -109.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 343, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 344, '  score:', -113.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 345, '  score:', -155.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 346, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 347, '  score:', -114.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 348, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 349, '  score:', -130.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 350, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 351, '  score:', -113.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 352, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 353, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 354, '  score:', -130.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 355, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 356, '  score:', -169.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 357, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 358, '  score:', -129.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 359, '  score:', -113.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 360, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 361, '  score:', -160.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 362, '  score:', -107.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 363, '  score:', -150.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 364, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 365, '  score:', -104.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 366, '  score:', -91.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 367, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 368, '  score:', -102.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 369, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 370, '  score:', -100.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 371, '  score:', -114.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 372, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 373, '  score:', -99.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 374, '  score:', -168.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 375, '  score:', -115.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 376, '  score:', -164.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 377, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 378, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 379, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 380, '  score:', -161.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 381, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 382, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 383, '  score:', -98.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 384, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 385, '  score:', -93.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 386, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 387, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 388, '  score:', -103.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 389, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 390, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 391, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 392, '  score:', -164.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 393, '  score:', -168.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 394, '  score:', -98.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 395, '  score:', -162.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 396, '  score:', -166.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 397, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 398, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 399, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 400, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 401, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 402, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 403, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 404, '  score:', -165.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 405, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 406, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 407, '  score:', -97.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 408, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 409, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 410, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 411, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 412, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 413, '  score:', -122.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 414, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 415, '  score:', -122.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 416, '  score:', -107.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 417, '  score:', -114.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 418, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 419, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 420, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 421, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 422, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 423, '  score:', -100.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 424, '  score:', -93.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 425, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 426, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 427, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 428, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 429, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 430, '  score:', -124.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 431, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 432, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 433, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 434, '  score:', -115.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 435, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 436, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 437, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 438, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 439, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 440, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 441, '  score:', -115.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 442, '  score:', -159.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 443, '  score:', -89.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 444, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 445, '  score:', -83.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 446, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 447, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 448, '  score:', -95.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 449, '  score:', -114.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 450, '  score:', -113.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 451, '  score:', -113.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 452, '  score:', -95.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 453, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 454, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 455, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 456, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 457, '  score:', -88.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 458, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 459, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 460, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 461, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 462, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 463, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 464, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 465, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 466, '  score:', -95.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 467, '  score:', -120.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 468, '  score:', -122.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 469, '  score:', -123.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 470, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 471, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 472, '  score:', -121.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 473, '  score:', -127.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 474, '  score:', -122.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 475, '  score:', -119.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 476, '  score:', -123.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 477, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 478, '  score:', -118.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 479, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 480, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 481, '  score:', -97.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 482, '  score:', -84.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 483, '  score:', -124.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 484, '  score:', -117.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 485, '  score:', -143.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 486, '  score:', -113.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 487, '  score:', -126.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 488, '  score:', -115.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 489, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 490, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 491, '  score:', -149.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 492, '  score:', -87.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 493, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 494, '  score:', -163.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 495, '  score:', -85.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 496, '  score:', -113.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 497, '  score:', -116.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 498, '  score:', -115.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
# ('episode:', 499, '  score:', -115.0, '  memory length:', 10000, '  epsilon:', 0.004980100000801017)
